# %%
#pip install -U pymongo
pip install dnspython
# Out:
#   File "C:\Users\Uttam\AppData\Local\Temp/ipykernel_19436/2339811031.py", line 2
#     pip install dnspython
#               ^
# SyntaxError: invalid syntax

# %%
import sys
import pandas as pd
import pymongo
import json
import os
from pathlib import Path

# %%
##def import_content(collName, filepath):
DatabaesName = 'Analytics'
collection_name = 'alternative'
filepath = r"Data\alternative.csv" 
##?retryWrites=true&w=majority
mng_client = pymongo.MongoClient('mongodb+srv://KUMAR:WelcomE01@cluster0.cep5x.mongodb.net/test')
mng_db = mng_client[DatabaesName] #// Replace mongo db name
#collection_name = collName #// Replace mongo db collection name
db_cm = mng_db[collection_name]
cdir = Path().resolve()
file_res = os.path.join(cdir, filepath)

data = pd.read_csv(file_res)
data_json = json.loads(data.to_json(orient='records'))
db_cm.insert_many(data_json)
    #db_cm.insert(data_json)
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19436/2931878907.py in <module>
#       4 filepath = r"Data\alternative.csv"
#       5 ##?retryWrites=true&w=majority
# ----> 6 mng_client = pymongo.MongoClient('mongodb+srv://KUMAR:WelcomE01@cluster0.cep5x.mongodb.net/test')
#       7 mng_db = mng_client[DatabaesName] #// Replace mongo db name
#       8 #collection_name = collName #// Replace mongo db collection name
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pymongo\mongo_client.py in __init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     679                     connect_timeout=timeout,
#     680                     srv_service_name=srv_service_name,
# --> 681                     srv_max_hosts=srv_max_hosts)
#     682                 seeds.update(res["nodelist"])
# ...

# %%
# Read data from Mongo DB to Pandas DataFrame

df = pd.DataFrame(list(db_cm.find()))

# %%
# Load data 
df.head(20)
# Out:
#                          _id    country Code  Year    TWh_Unit   source  \
# 0   621119ce3ad2db82e53c7f52  Argentina  ARG  2002    0.382037  Biofuel
# 1   621119ce3ad2db82e53c7f53  Argentina  ARG  2006    1.276533  Biofuel
# 2   621119ce3ad2db82e53c7f54  Argentina  ARG  1993    0.000000  Biofuel
# 3   621119ce3ad2db82e53c7f55  Argentina  ARG  2018  114.132343  Biofuel
# 4   621119ce3ad2db82e53c7f56  Argentina  ARG  2015    0.593335     Wind
# 5   621119ce3ad2db82e53c7f57  Argentina  ARG  2016    0.547359     Wind
# 6   621119ce3ad2db82e53c7f58  Argentina  ARG  1985    0.000000    Solar
# 7   621119ce3ad2db82e53c7f59  Argentina  ARG  1991    0.000000    Solar
# 8   621119ce3ad2db82e53c7f5a  Argentina  ARG  2003    0.000065    Solar
# 9   621119ce3ad2db82e53c7f5b  Argentina  ARG  2006    0.000090    Solar
# 10  621119ce3ad2db82e53c7f5c  Argentina  ARG  1974    5.028000    Hydro
# 11  621119ce3ad2db82e53c7f5d  Australia  AUS  1993    0.000000  Biofuel
# ...
